# %% [markdown]
# # Leitura do arquivo e configurações iniciais

# %%
# importa o dataset
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import math

history = []

import os
for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
nome_arquivo = './winequality/winequalityN.csv'
df=pd.read_csv(nome_arquivo) # Leitura do arquivo
df.head() # Visualização do arquivo
# Out:
# ./jupyter_local_teste.ipynb
# ./titanic.csv
# ./jupyter_local.ipynb
# ./lista4_eng.pdf
# ./winequality.zip
# ./winequality/winequalityN.csv
# ./.ipynb_checkpoints/jupyter_local_teste-checkpoint.ipynb
# ./.ipynb_checkpoints/jupyter_local-checkpoint.ipynb
# ./codigo_teste/weather_prevision.py
# ./codigo_teste/weatherAUS.csv
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
# Remove as linhas com dados vazios
from sklearn.preprocessing import LabelEncoder

print("Antes:", len(df.index) ,"linhas")


temp_data = df
le = LabelEncoder()
temp_data['type'] = le.fit_transform(temp_data['type'])
new_df = temp_data.dropna()
print("Depois:", len(new_df.index), "linhas")
new_df
# Out:
# Antes: 6497 linhas
# Depois: 6463 linhas
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     0            6.8             0.620         0.08             1.9
# 6492     0            6.2             0.600         0.08             2.0
# 6494     0            6.3             0.510         0.13             2.3
# 6495     0            5.9             0.645         0.12             2.0
# 6496     0            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6463 rows x 13 columns]

# %%
# Importa várias bibliotecas importantes
# Tensorflow / Keras

import tensorflow as tf # used to access argmax function
from tensorflow import keras # for building Neural Networks
#print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Dense, BatchNormalization # for creating regular densely-connected NN layer.

# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version

# Sklearn
import sklearn # for model evaluation
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.metrics import classification_report # for model evaluation metrics
# Out:
# pandas: 1.5.2
# numpy: 1.25.0
# sklearn: 1.2.0

# %% [markdown]
# # Treino

# %%
# Separa o dataset entre treino e teste
def dataset_split():
    # O atributo quality será utilizado como o verificador (r(valor_correto) - y(previsão))
    X= new_df.drop(["quality"] ,axis= 1)
    Y = new_df[['quality']]

    # Separa o dataset entre treino e teste. Sendo a proporção de 70% para o treino e 30% para o teste)
    X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size = 0.1, random_state = 0)
#     print("Shape of X_train: ", X_train.shape)
#     print("Shape of y_train: ", Y_train.shape)
#     print("Shape of X_test: ", X_test.shape)
#     print("Shape of y_test: ", Y_test.shape)
    return (X_train, Y_train, X_test, Y_test)

# %%
# Modelagem da rede neural


def ann_model(number_of_layers, minimum, maximum, input_size):
    model = Sequential(name = "DFF-Model")

    # Adiciona o input com normalização
    model.add(Input(shape=(input_size), name = 'Input-Layer'))
    model.add(BatchNormalization(synchronized=True))

    # Cria as hidden layers com batch normalization e relu
    for i in range(number_of_layers):
#         number_of_neurons = 32
#         if(i%2==0):
#             number_of_neurons = 64
        number_of_neurons = random.randint(minimum,maximum)
        name = 'Hidden-Layer-' + str(i)
        model.add(Dense(number_of_neurons, activation = 'relu', name = name))
        model.add(BatchNormalization(synchronized=True))


    model.add(Dense(11, activation = 'softmax', name = 'output'))
    return model

# %%
# Compila o modelo
def compile_the_model(model):
    # determina a função de perda
    model.compile(optimizer='adam',
                  loss='SparseCategoricalCrossentropy',
                  metrics=['Accuracy'],
                  run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
                  steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
                 )
    return model

# %%
# Treina o modelo.
def train_model(model,X_train, Y_train):
    
    # Condição de parada caso não haja melhora na acurácia dos dados de validação nas últimas 5 verificações.
    early_stopping = EarlyStopping(monitor='val_loss', patience = 5)

    model.fit(
        x=X_train,
        y=Y_train,
        #batch_size=None,
        epochs= 100,
        verbose=0,#verbose='auto',
        callbacks=None,
        validation_split=0.2, # tamanho do dataset de validação
        #validation_data=None,
        shuffle=True,
        class_weight=None,
        sample_weight=None,
        initial_epoch=0,
        steps_per_epoch=None,
        validation_steps=None,
        validation_batch_size=None,
        validation_freq=3,
        max_queue_size=10,
        workers=1,
        use_multiprocessing=False
    )
    return model

# %% [markdown]
# # Acurácia do modelo

# %%
# Retorna a acurácia do modelo
def accuracy_analysis(y_test, y_pred, name):
    return  accuracy_score(y_test,y_pred)*100
    

def model_accuracy(model,X_train, Y_train,X_test,Y_test):

    # Predict class labels on training data
    pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train),axis=1))
    # Predict class labels on a test data
    pred_labels_te = np.array(tf.math.argmax(model.predict(X_test),axis=1))
    tr_ac = accuracy_analysis(Y_train, pred_labels_tr,"training")
    tst_ac = accuracy_analysis(Y_test, pred_labels_te,"test")
  
    return (tr_ac,tst_ac)

# %%
from sklearn.model_selection import train_test_split
import random
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# Procura qual a melhor arquitetura por brute force

best = []
melhor = 0
for i in range(2,8):
    for k in range(2,10):
        for j in range(3):
            number_of_layers = (i)
            minimum = k
            maximum = minimum*2


            (X_train, Y_train,X_test,Y_test) = dataset_split()
            model = ann_model(number_of_layers, minimum , maximum, X_train.shape[1])
            model = compile_the_model(model)
            model = train_model(model, X_train, Y_train)
            (tr_ac,tst_ac) = model_accuracy(model, X_train, Y_train,X_test,Y_test)



            history.append((number_of_layers, minimum , maximum,tr_ac,tst_ac))
            if(tst_ac > melhor):
                melhor = tst_ac
                best_model = model
                best_dataset = [X_train, Y_train, X_test, Y_test]
            print(history[-1])
    
    
    
    
        print("----------------------------------\n\n")
        
    print("----------------------------------")
    print("----------------------------------")
    print("----------------------------------\n\n")

history
# Out:
# 182/182 [==============================] - 0s 606us/step
# 21/21 [==============================] - 0s 644us/step
# (2, 2, 4, 55.70839064649243, 56.10510046367851)
# 182/182 [==============================] - 0s 513us/step
# 21/21 [==============================] - 0s 617us/step
# (2, 2, 4, 54.573590096286104, 55.79598145285936)
# 182/182 [==============================] - 0s 583us/step
# 21/21 [==============================] - 0s 592us/step
# (2, 2, 4, 55.63961485557084, 56.10510046367851)
# ----------------------------------
#
#
# 182/182 [==============================] - 0s
#  (6, 4, 8, 56.94635488308115, 56.10510046367851),
#  (6, 4, 8, 57.39339752407153, 55.486862442040184),
#  (6, 4, 8, 56.92916093535075, 55.17774343122102),
#  (6, 5, 10, 57.015130674002755, 54.71406491499228),
#  (6, 5, 10, 57.46217331499312, 55.17774343122102),
#  (6, 5, 10, 57.20426409903714, 55.641421947449764),
#  (6, 6, 12, 58.08115543328748, 56.87789799072643),
#  (6, 6, 12, 56.99793672627235, 58.11437403400309),
#  (6, 6, 12, 57.444979367262725, 57.03245749613601),
#  (6, 7, 14, 59.09559834938102, 60.432766615146825),
#  (6, 7, 14, 58.442228335625856, 57.18701700154559),
#  (6, 7, 14, 58.717331499312245, 57.03245749613601),
#  (6, 8, 16, 59.19876203576341, 56.414219474497685),
#  (6, 8, 16, 58.04676753782668, 55.79598145285936),
#  (6, 8, 16, 58.098349381017876, 57.80525502318392),
#  (6, 9, 18, 60.41953232462174, 57.80525502318392),
#  (6, 9, 18, 59.83493810178817, 55.02318392581144),
#  (6, 9, 18, 58.94085281980743, 58.887171561051),
#  (7, 2, 4, 55.43328748280605, 55.486862442040184),
#  (7, 2, 4, 55.20976616231087, 57.496136012364765),
#  (7, 2, 4, 54.040577716643746, 52.85935085007728),
#  (7, 3, 6, 55.055020632737275, 53.63214837712519),
#  (7, 3, 6, 55.261348005502064, 52.7047913446677),
#  (7, 3, 6, 56.82599724896836, 55.332302936630605),
#  (7, 4, 8, 56.550894085281975, 57.18701700154559),
#  (7, 4, 8, 55.03782668500688, 55.486862442040184),
#  (7, 4, 8, 55.20976616231087, 54.404945904173104),
#  (7, 5, 10, 56.99793672627235, 58.42349304482226),
#  (7, 5, 10, 56.91196698762035, 57.18701700154559),
#  (7, 5, 10, 56.92916093535075, 57.341576506955185),
#  (7, 6, 12, 58.218707015130676, 58.26893353941267),
#  (7, 6, 12, 58.098349381017876, 57.18701700154559),
#  (7, 6, 12, 57.943603851444294, 56.568778979907265),
#  (7, 7, 14, 57.25584594222833, 57.341576506955185),
#  (7, 7, 14, 58.562585969738656, 57.341576506955185),
#  (7, 7, 14, 58.889270976616224, 56.414219474497685),
#  (7, 8, 16, 58.218707015130676, 55.486862442040184),
#  (7, 8, 16, 58.59697386519945, 57.341576506955185),
#  (7, 8, 16, 59.869325997248964, 56.10510046367851),
#  (7, 9, 18, 59.233149931224204, 56.568778979907265),
#  (7, 9, 18, 60.09284731774416, 58.11437403400309),
#  (7, 9, 18, 58.39064649243466, 54.86862442040186)]

# %% [markdown]
# ## Impressão da melhor arquitetura

# %%
def accuracy_analysis2(y_test, y_pred, name):
      
    print("Confusion Matrix: ",
        confusion_matrix(y_test, y_pred))
    
    print ("Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
    
    
    print("Report : ",
    classification_report(y_test, y_pred, zero_division=0))
   
    
def model_accuracy2(model,X_train, Y_train,X_test,Y_test):

    # Predict class labels on training data
    pred_labels_tr = np.array(tf.math.argmax(model.predict(X_train),axis=1))
    # Predict class labels on a test data
    pred_labels_te = np.array(tf.math.argmax(model.predict(X_test),axis=1))

    ##### Step 5 - Model Performance Summary
    print("")
    print('-------------------- Model Summary --------------------')
    model.summary()
    print("")
    
    print("")
    print('---------- Evaluation on Training Data ----------')
    accuracy_analysis2(Y_train, pred_labels_tr,"training")
    

    print('---------- Evaluation on Test Data ----------')
    accuracy_analysis2(Y_test, pred_labels_te,"test")

# %%
X_train = best_dataset [0]
Y_train = best_dataset [1]
X_test = best_dataset [2]
Y_test = best_dataset [3]
model_accuracy2(best_model, X_train, Y_train,X_test,Y_test)
# Out:
# 182/182 [==============================] - 0s 648us/step
# 21/21 [==============================] - 0s 747us/step
#
# -------------------- Model Summary --------------------
# Model: "DFF-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_546 (B  (None, 12)                48
#  atchNormalization)
#
#  Hidden-Layer-0 (Dense)      (None, 13)                169
#
#  batch_normalization_547 (B  (None, 13)                52
#  atchNormalization)
#
#  Hidden-Layer-1 (Dense)      (None, 9)                 126
#
#  batch_normalization_548 (B  (None, 9)                 36
#  atchNormalization)
#
#  Hidden-Layer-2 (Dense)      (None, 8)                 80
#
#  batch_normalization_549 (B  (None, 8)                 32
#  atchNormalization)
#
#  Hidden-Layer-3 (Dense)      (None, 13)                117
#
#  batch_normalization_550 (B  (None, 13)                52
#  atchNormalization)
#
#  Hidden-Layer-4 (Dense)      (None, 8)                 112
#
#  batch_normalization_551 (B  (None, 8)                 32
#  atchNormalization)
#
#  Hidden-Layer-5 (Dense)      (None, 7)                 63
#
#  batch_normalization_552 (B  (None, 7)                 28
#  atchNormalization)
#
#  output (Dense)              (None, 11)                88
#
# =================================================================
# Total params: 1035 (4.04 KB)
# Trainable params: 895 (3.50 KB)
# Non-trainable params: 140 (560.00 Byte)
# _________________________________________________________________
#
#
# ---------- Evaluation on Training Data ----------
# Confusion Matrix:  [[   2    4   12    9    1    0    0]
#  [   0   31  110   50    2    0    0]
#  [   0   19 1272  625   10    0    0]
#  [   1    5  540 1771  194    0    0]
#  [   0    0   29  583  361    0    0]
#  [   0    0    3   79   98    0    0]
#  [   0    0    0    1    4    0    0]]
# Accuracy :  59.09559834938102
# Report :                precision    recall  f1-score   support
#
#            3       0.67      0.07      0.13        28
#            4       0.53      0.16      0.25       193
#            5       0.65      0.66      0.65      1926
#            6       0.57      0.71      0.63      2511
#            7       0.54      0.37      0.44       973
#            8       0.00      0.00      0.00       180
#            9       0.00      0.00      0.00         5
#
#     accuracy                           0.59      5816
#    macro avg       0.42      0.28      0.30      5816
# weighted avg       0.57      0.59      0.57      5816
#
# ---------- Evaluation on Test Data ----------
# Confusion Matrix:  [[  0   0   1   1   0   0]
#  [  0   2  15   4   0   0]
#  [  0   2 137  61   2   0]
#  [  0   0  65 221  23   0]
#  [  0   0   1  69  31   0]
#  [  0   0   0   5   7   0]]
# Accuracy :  60.432766615146825
# Report :                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.50      0.10      0.16        21
#            5       0.63      0.68      0.65       202
#            6       0.61      0.72      0.66       309
#            7       0.49      0.31      0.38       101
#            8       0.00      0.00      0.00        12
#
#     accuracy                           0.60       647
#    macro avg       0.37      0.30      0.31       647
# weighted avg       0.58      0.60      0.58       647
